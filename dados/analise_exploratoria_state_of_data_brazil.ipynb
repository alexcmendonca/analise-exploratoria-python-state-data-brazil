# %% [markdown]
# #**Análise Exploratória de Dados com Python: State of Data Brazil**#

# %% [markdown]
# #**Tópicos**#
#
# 1. Introdução;
# 2. Exploração;
# 3. Processamento;
# 4. Agrupamentos e Agregações;
# 5. Visualização;
# P. Finalizando o projeto;
# 7. Divulgação.

# %% [markdown]
# ##1. Introdução

# %% [markdown]
# Entender o contexto do negócio utilizando o Google Colab

# %% [markdown]
# **1.1. Contexto**

# %% [markdown]
# O **State of Data Brazil** ([link](https://www.bain.com/contentassets/16494c60fcd045188615f05e728385b3/state-of-data2022_um-raio-x-dos-profissionais-de-dados-do-brasil.pdf)), realizada pelo [Data Hackers](https://www.datahackers.com.br/) e pela [Bain & Company](https://www.bain.com/), é uma das
# maiores pesquisas sobre o mercado brasileiro de dados. Dentre os assuntos pesquisado na
# última pesquisa (2022), foi mapeado o peral atual das três maiores profissões da área de
# dados do Brasil: **engenheiro de dados**, **cientista de dados** e **analista de dados**. O relatório
# completo pode ser acessado neste [link](https://www.stateofdata.com.br/).

# %% [markdown]
#     Figura 01: Remuneração em 2022 por nível de cargo.
#
# ---
#
# ![stateofbrazil-2022.png](data:image/png;base64,...)

# %% [markdown]
# ##2. Exploração

# %% [markdown]
# **2.1. Dados**
#
# Os dados da pesquisa foram disponibilizados no site do Kaggle ([link](https://www.kaggle.com/datasets/datahackers/state-of-data-2022)). O arquivo está no
# formato **CSV** (do inglês valores separados por vírgula), possuí **353 colunas** e **4271 linhas** e
# "pesa" por volta de **10 MB**.

# %% [markdown]
# **2.2. Upload**
#
# Download do arquivo no Kaggle ([link](https://www.kaggle.com/datasets/datahackers/state-of-data-2022)), formato CSV e realização do upload no ambiente do Google Colab.

# %% [markdown]
# **2.3. Exploração**

# %% [markdown]
# Na etapa de exploração, encontrar as colunas de interesse: **cargo**, **experiência** e **salário**.
# Vamos começar extraindo o cabeçalho do arquivo como um texto, ou *string* em Python.

# %%
# abrir arquivo csv no modo de leitura, realizando leitura da primeira linha e armazenando conteúdo na variável 'header'
# o with garante que o arquivo seja fechado automaticamente após a conclusão de leitura da linha
with open(file="State_of_data_2022.csv", mode="r") as fp:
  header = fp.readline()

# %%
# consultando o tipo de dado da variável
type(header)
# Out:
# str

# %%
# imprimir os primeiros 200 caracteres da variável
print(header[0:200])
# Out:
# "('P0', 'id')","('P1_a ', 'Idade')","('P1_a_1 ', 'Faixa idade')","('P1_b ', 'Genero')","('P1_c ', 'Cor/raca/etnia')","('P1_d ', 'PCD')","('P1_e ', 'experiencia_profissional_prejudicada')","('P1_f ', '

# %% [markdown]
# Transformar o texto do cabeçalho em uma lista de textos e listar apenas os
# elementos que representam as perguntas da segunda parte (carreira), ou seja, aqueles
# elementos de texto que apresentam as letras **P2**.

# %%
# dividir a string da variável 'header' em uma lista de substrings
header = header.split(sep='","')

# %%
# consultando o tipo de dado da variável
type(header)
# Out:
# list

# %%
# imprimir os 10 primeiros elementos da lista
print(header[0:10])
# Out:
# ['"(\'P0\', \'id\')', "('P1_a ', 'Idade')", "('P1_a_1 ', 'Faixa idade')", "('P1_b ', 'Genero')", "('P1_c ', 'Cor/raca/etnia')", "('P1_d ', 'PCD')", "('P1_e ', 'experiencia_profissional_prejudicada')", "('P1_f ', 'aspectos_prejudicados')", "('P1_g ', 'vive_no_brasil')", "('P1_i ', 'Estado onde mora')"]

# %%
# imprimir o segundo elemento da lista
print(header[1])
# Out:
# ('P1_a ', 'Idade')

# %%
# percorrendo todos os nomes das colunas e imprime o índice e o nome das colunas que contêm 'P2'
for column, column_name in enumerate(header):
  if 'P2' in column_name:
    print(str(column) + ' ' + (column_name))
# Out:
# 16 ('P2_a ', 'Qual sua situação atual de trabalho?')
# 17 ('P2_b ', 'Setor')
# 18 ('P2_c ', 'Numero de Funcionarios')
# 19 ('P2_d ', 'Gestor?')
# 20 ('P2_e ', 'Cargo como Gestor')
# 21 ('P2_f ', 'Cargo Atual')
# 22 ('P2_g ', 'Nivel')
# 23 ('P2_h ', 'Faixa salarial')
# 24 ('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')
# 25 ('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')
# 26 ('P2_k ', 'Você está satisfeito na sua empresa atual?')
# 27 ('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')
# 28 ('P2_l_1 ', 'Falta de oportunidade de crescimento no emprego atual')
# 29 ('P2_l_2 ', 'Salário atual não corresponde ao mercado')
# 30 ('P2_l_3 ', 'Não tenho uma boa relação com meu líder/gestor')
# 31 ('P2_l_4 ', 'Gostaria de trabalhar em em outra área de atuação')
# 32 ('P2_l_5 ', 'Gostaria de receber mais benefícios')
# ...

# %%
# acessando conteúdo pelo índice desejado se as condições forem atendidas
for column, column_name in enumerate(header):
  if 'P2' in column_name:
    if column in range(21, 24):
      print(str(column) + ' ' + (column_name))
# Out:
# 21 ('P2_f ', 'Cargo Atual')
# 22 ('P2_g ', 'Nivel')
# 23 ('P2_h ', 'Faixa salarial')

# %%
# realizando abertura novamente do arquivo csv no modo de leitura, realizando leitura da primeira linha e armazenao conteúdo na variável 'header'
with open(file="State_of_data_2022.csv", mode="r") as fp:
  header = fp.readline()

  for _ in range(10):
    line = fp.readline() # guardando conteúdo no formato texto
    line = line.split(sep=',') # guardando conteúdo no formato lista
    print({'Cargo': line[21], 'Experiencia': line[22], 'Salário': line[23]})
# Out:
# {'Cargo': 'DBA/Administrador de Banco de Dados', 'Experiencia': 'Júnior', 'Salário': 'de R$ 8.001/mês a R$ 12.000/mês'}
# {'Cargo': 'Supervisor/Coordenador', 'Experiencia': '', 'Salário': ''}
# {'Cargo': 'Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas', 'Experiencia': 'Pleno', 'Salário': 'de R$ 12.001/mês a R$ 16.000/mês'}
# {'Cargo': 'Cientista de Dados/Data Scientist', 'Experiencia': 'Sênior', 'Salário': 'de R$ 12.001/mês a R$ 16.000/mês'}
# {'Cargo': 'Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas', 'Experiencia': 'Pleno', 'Salário': 'de R$ 6.001/mês a R$ 8.000/mês'}
# {'Cargo': 'Professor', 'Experiencia': 'Pleno', 'Salário': 'de R$ 2.001/mês a R$ 3.000/mês'}
# {'Cargo': 'Analista de BI/BI Analyst', 'Experiencia': 'Júnior', 'Salário': 'de R$ 4.001/mês a R$ 6.000/mês'}
# {'Cargo': 'Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas', 'Experiencia': 'Júnior', 'Salário': 'de R$ 2.001/mês a R$ 3.000/mês'}
# ...

# %% [markdown]
# ###**Exercício 02: Utilizar o python para listar o nome e o tipo das colunas**###

# %%
# importando biblioteca Pandas do Python
import pandas as pd

# realizando leitura do arquivo csv e carregando os dados em um dataframe
df_base = pd.read_csv('State_of_data_2022.csv', sep=',')

# %%
# consultando informações sobre dataframe
df_base.dtypes
# Out:
# ('P0', 'id')                                                                                                                   object
# ('P1_a ', 'Idade')                                                                                                            float64
# ('P1_a_1 ', 'Faixa idade')                                                                                                     object
# ('P1_b ', 'Genero')                                                                                                            object
# ('P1_c ', 'Cor/raca/etnia')                                                                                                    object
#                                                                                                                                ...
# ('P8_d_7 ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')            float64
# ...

# %% [markdown]
# ##3. Processamento

# %%
data = list()

with open(file='State_of_data_2022.csv', mode='r') as fp:
  header = fp.readline()
  line = fp.readline() #linhas com texto

  while line:
    line = line.split(sep=',') # linha como lista
    data.append({'Cargo': line[21], 'Experiência': line[22], 'Salário': line[23]})
    line = fp.readline() # linhas como texto

# %%
for datum in data[0:10]:
  print(datum)
# Out:
# {'Cargo': 'DBA/Administrador de Banco de Dados', 'Experiência': 'Júnior', 'Salário': 'de R$ 8.001/mês a R$ 12.000/mês'}
# {'Cargo': 'Supervisor/Coordenador', 'Experiência': '', 'Salário': ''}
# {'Cargo': 'Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas', 'Experiência': 'Pleno', 'Salário': 'de R$ 12.001/mês a R$ 16.000/mês'}
# {'Cargo': 'Cientista de Dados/Data Scientist', 'Experiência': 'Sênior', 'Salário': 'de R$ 12.001/mês a R$ 16.000/mês'}
# {'Cargo': 'Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas', 'Experiência': 'Pleno', 'Salário': 'de R$ 6.001/mês a R$ 8.000/mês'}
# {'Cargo': 'Professor', 'Experiência': 'Pleno', 'Salário': 'de R$ 2.001/mês a R$ 3.000/mês'}
# {'Cargo': 'Analista de BI/BI Analyst', 'Experiência': 'Júnior', 'Salário': 'de R$ 4.001/mês a R$ 6.000/mês'}
# {'Cargo': 'Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas', 'Experiência': 'Júnior', 'Salário': 'de R$ 2.001/mês a R$ 3.000/mês'}
# ...

# %%
# consultando tamanho da base
len(data)
# Out:
# 4271

# %% [markdown]
# **3.1. Pandas**

# %% [markdown]
# Vamos utilizar o Pandas ([documentação](https://pandas.pydata.org/docs/reference/frame.html)), o pacote **Python** mais utilizado para processamento de dados.

# %%
# importando biblioteca Pandas do Python
import pandas as pd

# %% [markdown]
# **3.2. DataFrame**

# %% [markdown]
# A abstração base do Pandas é o DataFrame, uma estrutura de dados que representa uma tabela de duas dimensões.

# %%
# criando um dataframe usando a estrutura de dados 'data'
data_table = pd.DataFrame(data)

# %%
# visualizando as primeiras 15 linhas do DataFrame
data_table.head(15)
# Out:
#                                                 Cargo     Experiência  \
# 0                 DBA/Administrador de Banco de Dados          Júnior
# 1                              Supervisor/Coordenador
# 2   Desenvolvedor/ Engenheiro de Software/ Analist...           Pleno
# 3                   Cientista de Dados/Data Scientist          Sênior
# 4   Desenvolvedor/ Engenheiro de Software/ Analist...           Pleno
# 5                                           Professor           Pleno
# 6                           Analista de BI/BI Analyst          Júnior
# 7   Desenvolvedor/ Engenheiro de Software/ Analist...          Júnior
# 8                           Analista de BI/BI Analyst          Sênior
# 9                                           Professor           Pleno
# 10                          Analista de BI/BI Analyst          Júnior
# 11  Analista de Inteligência de Mercado/Market Int...          Sênior
# 12
# 13              Analista de Negócios/Business Analyst          Júnior
# ...

# %%
# consultando a qtde de linhas e colunas no DataFrame
data_table.shape
# Out:
# (4271, 3)

# %%
# salvando o dataframe em um arquivo csv
# checkpoint realizado com execução das operações com os dados e salvando dados após tranformação inicial
data_table.to_csv('data.csv', header=True, index=False)

# %% [markdown]
# **3.3. Limpeza**

# %% [markdown]
# Um boa análise de dados só é possível com os dados consistentes, portando a limpeza do conjunto de dados se faz necessária.

# %% [markdown]
# * Linhas vazias

# %% [markdown]
# Existem diversas estratégias para lidar com dados faltantes, como a inputação ("força valor") ou a deleção (remover a linha toda). Utilizando a segunda opção.

# %%
# substituindo conteúdo vazio no df com NA
data_table = data_table.replace('', pd.NA)

# %%
data_table.head(15)
# Out:
#                                                 Cargo     Experiência  \
# 0                 DBA/Administrador de Banco de Dados          Júnior
# 1                              Supervisor/Coordenador            <NA>
# 2   Desenvolvedor/ Engenheiro de Software/ Analist...           Pleno
# 3                   Cientista de Dados/Data Scientist          Sênior
# 4   Desenvolvedor/ Engenheiro de Software/ Analist...           Pleno
# 5                                           Professor           Pleno
# 6                           Analista de BI/BI Analyst          Júnior
# 7   Desenvolvedor/ Engenheiro de Software/ Analist...          Júnior
# 8                           Analista de BI/BI Analyst          Sênior
# 9                                           Professor           Pleno
# 10                          Analista de BI/BI Analyst          Júnior
# 11  Analista de Inteligência de Mercado/Market Int...          Sênior
# ...

# %%
# excluindo toda linha que contem NA
data_table = data_table.dropna()

# %%
# consultando tamanho atualizado do df após exclusão NA
data_table.shape
# Out:
# (2790, 3)

# %%
# consultando a porcentagem dos valores disponíveis da base após limpeza
2790 / 4271 * 100
# Out:
# 65.32428002809645

# %% [markdown]
# * Linhas corrompidas

# %% [markdown]
# Linhas corrompidas podem derivar de diversos fatores: erros de processamento, erros humanos, etc. Podemos manual ou automaticamente corrigi-las, ou ainda aplicar a técnica de deleção vista anteriormente. Utilizando a última opção.

# %%
# preenchendo coluna 'Salário' com NA caso a função lambda não encontre a string 'RS'
data_table['Salário'] = data_table['Salário'].apply(lambda row: row if 'R$' in row else pd.NA)

#data_table['Salário'] = data_table['Salário'].apply(lambda row: row if pd.isna(row) or 'R$' in row else pd.NA)

# %%
# consultando dados atualizados no dataframe
data_table.head(15)
# Out:
#                                                 Cargo     Experiência  \
# 0                 DBA/Administrador de Banco de Dados          Júnior
# 2   Desenvolvedor/ Engenheiro de Software/ Analist...           Pleno
# 3                   Cientista de Dados/Data Scientist          Sênior
# 4   Desenvolvedor/ Engenheiro de Software/ Analist...           Pleno
# 5                                           Professor           Pleno
# 6                           Analista de BI/BI Analyst          Júnior
# 7   Desenvolvedor/ Engenheiro de Software/ Analist...          Júnior
# 8                           Analista de BI/BI Analyst          Sênior
# 9                                           Professor           Pleno
# 10                          Analista de BI/BI Analyst          Júnior
# 11  Analista de Inteligência de Mercado/Market Int...          Sênior
# 13              Analista de Negócios/Business Analyst          Júnior
# ...

# %%
# excluindo toda linha que contem NA
data_table = data_table.dropna()

# %%
# nova consulta no dataframe
data_table.head(15)
# Out:
#                                                 Cargo Experiência  \
# 0                 DBA/Administrador de Banco de Dados      Júnior
# 2   Desenvolvedor/ Engenheiro de Software/ Analist...       Pleno
# 3                   Cientista de Dados/Data Scientist      Sênior
# 4   Desenvolvedor/ Engenheiro de Software/ Analist...       Pleno
# 5                                           Professor       Pleno
# 6                           Analista de BI/BI Analyst      Júnior
# 7   Desenvolvedor/ Engenheiro de Software/ Analist...      Júnior
# 8                           Analista de BI/BI Analyst      Sênior
# 9                                           Professor       Pleno
# 10                          Analista de BI/BI Analyst      Júnior
# 11  Analista de Inteligência de Mercado/Market Int...      Sênior
# 13              Analista de Negócios/Business Analyst      Júnior
# 15                          Analista de BI/BI Analyst       Pleno
# ...

# %%
# consultando tamanho atualizado do dataframe
data_table.shape
# Out:
# (2386, 3)

# %%
# consultando a porcentagem atualizada da base após limpeza da base original
2386 / 4271 * 100
# Out:
# 55.86513697026457

# %% [markdown]
# * Linhas de interesse

# %% [markdown]
# A seleção dos dados de interesse também pode ocorrer a nível de linha. VAmos selecionar apenas as profissões de interesse: **analista**, **cientista** e **engenharia** de dados.

# %%
# selecionado dados únicos no dataframe
data_table['Cargo'].unique()
# Out:
# array(['DBA/Administrador de Banco de Dados',
#        'Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas',
#        'Cientista de Dados/Data Scientist', 'Professor',
#        'Analista de BI/BI Analyst',
#        'Analista de Inteligência de Mercado/Market Intelligence',
#        'Analista de Negócios/Business Analyst',
#        'Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect',
#        'Product Manager/ Product Owner (PM/APM/DPM/GPM/PO)',
#        'Analista de Dados/Data Analyst',
#        'Analista de Suporte/Analista Técnico', 'Outra Opção',
#        'Engenheiro de Machine Learning/ML Engineer', 'Analytics Engineer',
#        'Analista de Marketing', 'Outras Engenharias (não inclui dev)',
#        'Economista', 'Estatístico'], dtype=object)

# %%
# criando uma lista com apenas os cargos de interesse
positions = ['Analista de Dados/Data Analyst', 'Cientista de Dados/Data Scientist',  'Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect']

# %%
# filtrando dados na coluna 'cargo' com base na lista 'positions' aplicando a função lambda para manter apenas conteúdo da lista ou substituindo por NA
data_table['Cargo'] = data_table['Cargo'].apply(lambda row: row if row in positions else pd.NA)

# %%
data_table.head(15)
# Out:
#                                                 Cargo Experiência  \
# 0                                                <NA>      Júnior
# 2                                                <NA>       Pleno
# 3                   Cientista de Dados/Data Scientist      Sênior
# 4                                                <NA>       Pleno
# 5                                                <NA>       Pleno
# 6                                                <NA>      Júnior
# 7                                                <NA>      Júnior
# 8                                                <NA>      Sênior
# 9                                                <NA>       Pleno
# 10                                               <NA>      Júnior
# 11                                               <NA>      Sênior
# 13                                               <NA>      Júnior
# 15                                               <NA>       Pleno
# ...

# %%
data_table = data_table.dropna()

# %%
data_table.head(15)
# Out:
#                                                 Cargo Experiência  \
# 3                   Cientista de Dados/Data Scientist      Sênior
# 18  Engenheiro de Dados/Arquiteto de Dados/Data En...       Pleno
# 23  Engenheiro de Dados/Arquiteto de Dados/Data En...      Sênior
# 29                  Cientista de Dados/Data Scientist      Júnior
# 30                     Analista de Dados/Data Analyst      Júnior
# 31  Engenheiro de Dados/Arquiteto de Dados/Data En...      Júnior
# 37  Engenheiro de Dados/Arquiteto de Dados/Data En...      Júnior
# 41  Engenheiro de Dados/Arquiteto de Dados/Data En...      Júnior
# 45                  Cientista de Dados/Data Scientist      Sênior
# 49  Engenheiro de Dados/Arquiteto de Dados/Data En...      Sênior
# 51                  Cientista de Dados/Data Scientist       Pleno
# 53  Engenheiro de Dados/Arquiteto de Dados/Data En...       Pleno
# 57                     Analista de Dados/Data Analyst      Sênior
# ...

# %%
data_table.shape
# Out:
# (1336, 3)

# %%
1336 / 4271 * 100
# Out:
# 31.28073050807773

# %% [markdown]
# Para simplificar um pouco mais, podemos renomear as profissões

# %%
# criando nova lista com cargos resumidos
positions_update = ['Analista', 'Cientista', 'Engenharia']

# %%
# criando dicionário com função zip para combinar os elementos de duas listas
positions_update = dict(zip(positions, positions_update))

# %%
positions_update
# Out:
# {'Analista de Dados/Data Analyst': 'Analista',
#  'Cientista de Dados/Data Scientist': 'Cientista',
#  'Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect': 'Engenharia'}

# %%
# substituindo os valores da coluna 'Cargo' pelos valores correspondentes do dicionário 'positions_update'
data_table['Cargo'] = data_table['Cargo'].apply(lambda row: positions_update[row])
# Out:
# <ipython-input-43-0b695a1c56d5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_table['Cargo'] = data_table['Cargo'].apply(lambda row: positions_update[row])

# %%
data_table.head(15)
# Out:
#          Cargo Experiência                           Salário
# 3    Cientista      Sênior  de R$ 12.001/mês a R$ 16.000/mês
# 18  Engenharia       Pleno    de R$ 6.001/mês a R$ 8.000/mês
# 23  Engenharia      Sênior  de R$ 12.001/mês a R$ 16.000/mês
# 29   Cientista      Júnior   de R$ 8.001/mês a R$ 12.000/mês
# 30    Analista      Júnior    de R$ 3.001/mês a R$ 4.000/mês
# 31  Engenharia      Júnior    de R$ 2.001/mês a R$ 3.000/mês
# 37  Engenharia      Júnior    de R$ 2.001/mês a R$ 3.000/mês
# 41  Engenharia      Júnior    de R$ 4.001/mês a R$ 6.000/mês
# 45   Cientista      Sênior    de R$ 6.001/mês a R$ 8.000/mês
# 49  Engenharia      Sênior   de R$ 8.001/mês a R$ 12.000/mês
# 51   Cientista       Pleno    de R$ 6.001/mês a R$ 8.000/mês
# 53  Engenharia       Pleno   de R$ 8.001/mês a R$ 12.000/mês
# 57    Analista      Sênior    de R$ 4.001/mês a R$ 6.000/mês
# 58  Engenharia       Pleno   de R$ 8.001/mês a R$ 12.000/mês
# ...

# %%
# validando dados únicos na coluna 'Cargo'
data_table['Cargo'].unique()
# Out:
# array(['Cientista', 'Engenharia', 'Analista'], dtype=object)

# %%
data_table['Experiência'].unique()
# Out:
# array(['Sênior', 'Pleno', 'Júnior'], dtype=object)

# %%
data_table['Salário'].unique()
# Out:
# array(['de R$ 12.001/mês a R$ 16.000/mês',
#        'de R$ 6.001/mês a R$ 8.000/mês',
#        'de R$ 8.001/mês a R$ 12.000/mês',
#        'de R$ 3.001/mês a R$ 4.000/mês', 'de R$ 2.001/mês a R$ 3.000/mês',
#        'de R$ 4.001/mês a R$ 6.000/mês',
#        'de R$ 25.001/mês a R$ 30.000/mês',
#        'de R$ 30.001/mês a R$ 40.000/mês',
#        'de R$ 1.001/mês a R$ 2.000/mês', 'Acima de R$ 40.001/mês',
#        'de R$ 20.001/mês a R$ 25.000/mês',
#        'de R$ 16.001/mês a R$ 20.000/mês', 'Menos de R$ 1.000/mês'],
#       dtype=object)

# %%
# salvando o conjunto de dados limpos para aruivo CSV
data_table.to_csv('data_upd.csv', header=True, index=False)

# %% [markdown]
# ##4. Agrupamentos e Agregações

# %% [markdown]
# Nesta etapa aplicamos agrupamentos dos dados com operação matemática de soma em diversos níveis de agregação.

# %%
# status atual do tamanho do dataframe
data_table.shape
# Out:
# (1336, 3)

# %%
# leitura dos primeiros 15 registros do dataframe
data_table.head(15)
# Out:
#          Cargo Experiência                           Salário
# 3    Cientista      Sênior  de R$ 12.001/mês a R$ 16.000/mês
# 18  Engenharia       Pleno    de R$ 6.001/mês a R$ 8.000/mês
# 23  Engenharia      Sênior  de R$ 12.001/mês a R$ 16.000/mês
# 29   Cientista      Júnior   de R$ 8.001/mês a R$ 12.000/mês
# 30    Analista      Júnior    de R$ 3.001/mês a R$ 4.000/mês
# 31  Engenharia      Júnior    de R$ 2.001/mês a R$ 3.000/mês
# 37  Engenharia      Júnior    de R$ 2.001/mês a R$ 3.000/mês
# 41  Engenharia      Júnior    de R$ 4.001/mês a R$ 6.000/mês
# 45   Cientista      Sênior    de R$ 6.001/mês a R$ 8.000/mês
# 49  Engenharia      Sênior   de R$ 8.001/mês a R$ 12.000/mês
# 51   Cientista       Pleno    de R$ 6.001/mês a R$ 8.000/mês
# 53  Engenharia       Pleno   de R$ 8.001/mês a R$ 12.000/mês
# 57    Analista      Sênior    de R$ 4.001/mês a R$ 6.000/mês
# 58  Engenharia       Pleno   de R$ 8.001/mês a R$ 12.000/mês
# ...

# %%
# criando nova coluna no dataframe com valor unitário = 1
data_table['Quantidade'] = 1

# %%
data_table.head(15)
# Out:
#          Cargo Experiência                           Salário  Quantidade
# 3    Cientista      Sênior  de R$ 12.001/mês a R$ 16.000/mês           1
# 18  Engenharia       Pleno    de R$ 6.001/mês a R$ 8.000/mês           1
# 23  Engenharia      Sênior  de R$ 12.001/mês a R$ 16.000/mês           1
# 29   Cientista      Júnior   de R$ 8.001/mês a R$ 12.000/mês           1
# 30    Analista      Júnior    de R$ 3.001/mês a R$ 4.000/mês           1
# 31  Engenharia      Júnior    de R$ 2.001/mês a R$ 3.000/mês           1
# 37  Engenharia      Júnior    de R$ 2.001/mês a R$ 3.000/mês           1
# 41  Engenharia      Júnior    de R$ 4.001/mês a R$ 6.000/mês           1
# 45   Cientista      Sênior    de R$ 6.001/mês a R$ 8.000/mês           1
# 49  Engenharia      Sênior   de R$ 8.001/mês a R$ 12.000/mês           1
# 51   Cientista       Pleno    de R$ 6.001/mês a R$ 8.000/mês           1
# 53  Engenharia       Pleno   de R$ 8.001/mês a R$ 12.000/mês           1
# ...

# %% [markdown]
# **4.1. Por salário**

# %% [markdown]
# No primeiro nível de agregação, vamos contar quantos profissionais estão em cada faixa de salário.

# %%
# novo dataframe com a soma de cada valor único na coluna 'Salário' utilizando agregação
salario_agg = data_table[['Salário', 'Quantidade']].groupby('Salário').agg('sum').reset_index()

# %%
salario_agg.head(15)
# Out:
#                              Salário  Quantidade
# 0             Acima de R$ 40.001/mês          12
# 1              Menos de R$ 1.000/mês           8
# 2     de R$ 1.001/mês a R$ 2.000/mês          59
# 3   de R$ 12.001/mês a R$ 16.000/mês         192
# 4   de R$ 16.001/mês a R$ 20.000/mês          49
# 5     de R$ 2.001/mês a R$ 3.000/mês          75
# 6   de R$ 20.001/mês a R$ 25.000/mês          24
# 7   de R$ 25.001/mês a R$ 30.000/mês          13
# 8     de R$ 3.001/mês a R$ 4.000/mês          89
# 9   de R$ 30.001/mês a R$ 40.000/mês          17
# 10    de R$ 4.001/mês a R$ 6.000/mês         244
# 11    de R$ 6.001/mês a R$ 8.000/mês         234
# 12   de R$ 8.001/mês a R$ 12.000/mês         320

# %% [markdown]
# Uma operação comum sobre dados agregados é a ordenação. Como a coluna Salário não é
# numericamente ordenável (textos são ordenados por ordem alfabética da primeira letra),
# podemos manualmente definir uma coluna artificial de ordenamento.

# %%
# criando um dicionário para ordenação por salário
salario_ordem = {
'Menos de R$ 1.000/mês': 0,
'de R$ 1.001/mês a R$ 2.000/mês': 1,
'de R$ 2.001/mês a R$ 3.000/mês': 2,
'de R$ 3.001/mês a R$ 4.000/mês': 3,
'de R$ 4.001/mês a R$ 6.000/mês': 4,
'de R$ 6.001/mês a R$ 8.000/mês': 5,
'de R$ 8.001/mês a R$ 12.000/mês': 6,
'de R$ 12.001/mês a R$ 16.000/mês': 7,
'de R$ 16.001/mês a R$ 20.000/mês': 8,
'de R$ 20.001/mês a R$ 25.000/mês': 9,
'de R$ 25.001/mês a R$ 30.000/mês': 10,
'de R$ 30.001/mês a R$ 40.000/mês': 11,
'Acima de R$ 40.001/mês': 12
}

# %%
# adicionando nova coluna no dataframe e mapeando os valores únicos da coluna 'Salário' para os respectivos valores na coluna 'Ordem'
salario_agg['Ordem'] = salario_agg['Salário'].apply(lambda row: salario_ordem[row])

# %%
salario_agg.head(15)
# Out:
#                              Salário  Quantidade  Ordem
# 0             Acima de R$ 40.001/mês          12     12
# 1              Menos de R$ 1.000/mês           8      0
# 2     de R$ 1.001/mês a R$ 2.000/mês          59      1
# 3   de R$ 12.001/mês a R$ 16.000/mês         192      7
# 4   de R$ 16.001/mês a R$ 20.000/mês          49      8
# 5     de R$ 2.001/mês a R$ 3.000/mês          75      2
# 6   de R$ 20.001/mês a R$ 25.000/mês          24      9
# 7   de R$ 25.001/mês a R$ 30.000/mês          13     10
# 8     de R$ 3.001/mês a R$ 4.000/mês          89      3
# 9   de R$ 30.001/mês a R$ 40.000/mês          17     11
# 10    de R$ 4.001/mês a R$ 6.000/mês         244      4
# 11    de R$ 6.001/mês a R$ 8.000/mês         234      5
# 12   de R$ 8.001/mês a R$ 12.000/mês         320      6

# %%
# ordenando de forma ascendente o dataframe pelo salário
salario_agg = salario_agg.sort_values(by='Ordem', ascending=True)

# %%
salario_agg.head(15)
# Out:
#                              Salário  Quantidade  Ordem
# 1              Menos de R$ 1.000/mês           8      0
# 2     de R$ 1.001/mês a R$ 2.000/mês          59      1
# 5     de R$ 2.001/mês a R$ 3.000/mês          75      2
# 8     de R$ 3.001/mês a R$ 4.000/mês          89      3
# 10    de R$ 4.001/mês a R$ 6.000/mês         244      4
# 11    de R$ 6.001/mês a R$ 8.000/mês         234      5
# 12   de R$ 8.001/mês a R$ 12.000/mês         320      6
# 3   de R$ 12.001/mês a R$ 16.000/mês         192      7
# 4   de R$ 16.001/mês a R$ 20.000/mês          49      8
# 6   de R$ 20.001/mês a R$ 25.000/mês          24      9
# 7   de R$ 25.001/mês a R$ 30.000/mês          13     10
# 9   de R$ 30.001/mês a R$ 40.000/mês          17     11
# 0             Acima de R$ 40.001/mês          12     12

# %% [markdown]
# **4.2. Por salário e cargo**

# %% [markdown]
# No segundo nível de agregação, contando quantos proassionais estão em cada faixa de salário por cargo.

# %%
# agrupando os dados pelas colunas 'Cargo' e 'Salário'
salario_cargo_agg = data_table[['Cargo', 'Salário', 'Quantidade']].groupby(['Cargo', 'Salário']).agg('sum')
salario_cargo_agg
# Out:
#                                              Quantidade
# Cargo      Salário
# Analista   Acima de R$ 40.001/mês                     1
#            Menos de R$ 1.000/mês                      4
#            de R$ 1.001/mês a R$ 2.000/mês            28
#            de R$ 12.001/mês a R$ 16.000/mês          35
#            de R$ 16.001/mês a R$ 20.000/mês           6
#            de R$ 2.001/mês a R$ 3.000/mês            36
#            de R$ 20.001/mês a R$ 25.000/mês           4
#            de R$ 25.001/mês a R$ 30.000/mês           2
#            de R$ 3.001/mês a R$ 4.000/mês            59
#            de R$ 30.001/mês a R$ 40.000/mês           5
#            de R$ 4.001/mês a R$ 6.000/mês           122
#            de R$ 6.001/mês a R$ 8.000/mês            91
#            de R$ 8.001/mês a R$ 12.000/mês          106
# Cientista  Acima de R$ 40.001/mês                     5
#            Menos de R$ 1.000/mês                      4
# ...

# %%
# redefinindo o índice do dataframe
salario_cargo_agg.reset_index(inplace=True)

# %%
# adicionando nova coluna no dataframe e mapeando os valores únicos da coluna 'Salário' para os respectivos valores na coluna 'Ordem'
salario_cargo_agg['Ordem'] = salario_cargo_agg['Salário'].apply(lambda row: salario_ordem[row])

# %%
# classificando o dataframe primeiro pelo 'Cargo' e dentro de cada 'Cargo' classicando os salários de acordo com a ordem especificada
salario_cargo_agg = salario_cargo_agg.sort_values(by=['Cargo', 'Ordem'], ascending=[True, True])

# %%
salario_cargo_agg.head(100)
# Out:
#          Cargo                           Salário  Quantidade  Ordem
# 1     Analista             Menos de R$ 1.000/mês           4      0
# 2     Analista    de R$ 1.001/mês a R$ 2.000/mês          28      1
# 5     Analista    de R$ 2.001/mês a R$ 3.000/mês          36      2
# 8     Analista    de R$ 3.001/mês a R$ 4.000/mês          59      3
# 10    Analista    de R$ 4.001/mês a R$ 6.000/mês         122      4
# 11    Analista    de R$ 6.001/mês a R$ 8.000/mês          91      5
# 12    Analista   de R$ 8.001/mês a R$ 12.000/mês         106      6
# 3     Analista  de R$ 12.001/mês a R$ 16.000/mês          35      7
# 4     Analista  de R$ 16.001/mês a R$ 20.000/mês           6      8
# 6     Analista  de R$ 20.001/mês a R$ 25.000/mês           4      9
# 7     Analista  de R$ 25.001/mês a R$ 30.000/mês           2     10
# 9     Analista  de R$ 30.001/mês a R$ 40.000/mês           5     11
# 0     Analista            Acima de R$ 40.001/mês           1     12
# ...

# %%
# classificando o DataFrame salario_cargo_agg com base nas colunas 'Ordem' e 'Cargo' em ordem ascendente.
salario_cargo_agg = salario_cargo_agg.sort_values(by=['Ordem', 'Cargo'], ascending=[True, True])

# %%
salario_cargo_agg.head(100)
# Out:
#          Cargo                           Salário  Quantidade  Ordem
# 1     Analista             Menos de R$ 1.000/mês           4      0
# 14   Cientista             Menos de R$ 1.000/mês           4      0
# 2     Analista    de R$ 1.001/mês a R$ 2.000/mês          28      1
# 15   Cientista    de R$ 1.001/mês a R$ 2.000/mês          16      1
# 27  Engenharia    de R$ 1.001/mês a R$ 2.000/mês          15      1
# 5     Analista    de R$ 2.001/mês a R$ 3.000/mês          36      2
# 18   Cientista    de R$ 2.001/mês a R$ 3.000/mês          24      2
# 30  Engenharia    de R$ 2.001/mês a R$ 3.000/mês          15      2
# 8     Analista    de R$ 3.001/mês a R$ 4.000/mês          59      3
# 21   Cientista    de R$ 3.001/mês a R$ 4.000/mês          18      3
# 33  Engenharia    de R$ 3.001/mês a R$ 4.000/mês          12      3
# 10    Analista    de R$ 4.001/mês a R$ 6.000/mês         122      4
# 23   Cientista    de R$ 4.001/mês a R$ 6.000/mês          59      4
# ...

# %% [markdown]
# **4.3. Por salário, cargo e experiência**

# %% [markdown]
# Por fim, no terceiro nível de agregação, contando quantos profissionais estão em cada faixa de salário por cargo e nivel de experiência.

# %%
salario_cargo_experiencia_agg = data_table[['Cargo', 'Experiência', 'Salário', 'Quantidade']].groupby(['Cargo', 'Experiência', 'Salário']).agg('sum').reset_index()

# %%
# adicionando nova coluna no dataframe e mapeando os valores únicos da coluna 'Salário' para os respectivos valores na coluna 'Ordem'
salario_cargo_experiencia_agg['Ordem'] = salario_cargo_experiencia_agg['Salário'].apply(lambda row: salario_ordem[row])

# %%
# classificando o dataframe com base em três colunas
salario_cargo_experiencia_agg = salario_cargo_experiencia_agg.sort_values(by=['Cargo', 'Experiência', 'Ordem'], ascending=[True, True, True])

# %%
salario_cargo_experiencia_agg.head(15)
# Out:
#        Cargo Experiência                           Salário  Quantidade  Ordem
# 0   Analista      Júnior             Menos de R$ 1.000/mês           4      0
# 1   Analista      Júnior    de R$ 1.001/mês a R$ 2.000/mês          26      1
# 2   Analista      Júnior    de R$ 2.001/mês a R$ 3.000/mês          34      2
# 3   Analista      Júnior    de R$ 3.001/mês a R$ 4.000/mês          46      3
# 4   Analista      Júnior    de R$ 4.001/mês a R$ 6.000/mês          54      4
# 5   Analista      Júnior    de R$ 6.001/mês a R$ 8.000/mês          12      5
# 6   Analista      Júnior   de R$ 8.001/mês a R$ 12.000/mês           1      6
# 7   Analista       Pleno    de R$ 1.001/mês a R$ 2.000/mês           1      1
# 10  Analista       Pleno    de R$ 2.001/mês a R$ 3.000/mês           2      2
# 13  Analista       Pleno    de R$ 3.001/mês a R$ 4.000/mês          12      3
# 14  Analista       Pleno    de R$ 4.001/mês a R$ 6.000/mês          60      4
# ...

# %%
# analisando a distribuição apenas por analistas de dados
salario_cargo_experiencia_agg[salario_cargo_experiencia_agg['Cargo'] == 'Analista'].head(30)
# Out:
#        Cargo Experiência                           Salário  Quantidade  Ordem
# 0   Analista      Júnior             Menos de R$ 1.000/mês           4      0
# 1   Analista      Júnior    de R$ 1.001/mês a R$ 2.000/mês          26      1
# 2   Analista      Júnior    de R$ 2.001/mês a R$ 3.000/mês          34      2
# 3   Analista      Júnior    de R$ 3.001/mês a R$ 4.000/mês          46      3
# 4   Analista      Júnior    de R$ 4.001/mês a R$ 6.000/mês          54      4
# 5   Analista      Júnior    de R$ 6.001/mês a R$ 8.000/mês          12      5
# 6   Analista      Júnior   de R$ 8.001/mês a R$ 12.000/mês           1      6
# 7   Analista       Pleno    de R$ 1.001/mês a R$ 2.000/mês           1      1
# 10  Analista       Pleno    de R$ 2.001/mês a R$ 3.000/mês           2      2
# 13  Analista       Pleno    de R$ 3.001/mês a R$ 4.000/mês          12      3
# 14  Analista       Pleno    de R$ 4.001/mês a R$ 6.000/mês          60      4
# ...

# %% [markdown]
# ##5. Visualização

# %% [markdown]
# Visualizando os dados agregados

# %%
# analisando a distribuição apenas por analistas de dados
salario_cargo_experiencia_agg[salario_cargo_experiencia_agg['Cargo'] == 'Analista'].head(30)
# Out:
#        Cargo Experiência                           Salário  Quantidade  Ordem
# 0   Analista      Júnior             Menos de R$ 1.000/mês           4      0
# 1   Analista      Júnior    de R$ 1.001/mês a R$ 2.000/mês          26      1
# 2   Analista      Júnior    de R$ 2.001/mês a R$ 3.000/mês          34      2
# 3   Analista      Júnior    de R$ 3.001/mês a R$ 4.000/mês          46      3
# 4   Analista      Júnior    de R$ 4.001/mês a R$ 6.000/mês          54      4
# 5   Analista      Júnior    de R$ 6.001/mês a R$ 8.000/mês          12      5
# 6   Analista      Júnior   de R$ 8.001/mês a R$ 12.000/mês           1      6
# 7   Analista       Pleno    de R$ 1.001/mês a R$ 2.000/mês           1      1
# 10  Analista       Pleno    de R$ 2.001/mês a R$ 3.000/mês           2      2
# 13  Analista       Pleno    de R$ 3.001/mês a R$ 4.000/mês          12      3
# 14  Analista       Pleno    de R$ 4.001/mês a R$ 6.000/mês          60      4
# ...

# %% [markdown]
# **5.1. Seaborn**

# %% [markdown]
# Utilizando o Seaborn ([documentação](https://seaborn.pydata.org/api.html)), um dos pacotes **Python** mais utilizado para visualização de dados.

# %%
import seaborn as sns

# %% [markdown]
# **5.2. Por salário**

# %% [markdown]
# No primeiro nível, vamos utilizar um gráfico de barras. No eixo **x** temos o **salário**
# (representado pela sua ordem) e no eixo **y**, a **quantidade** de profissionais. A cor das barras e
# a legenda também representam o **salário**.

# %%
salario_agg.head(15)
# Out:
#                              Salário  Quantidade  Ordem
# 1              Menos de R$ 1.000/mês           8      0
# 2     de R$ 1.001/mês a R$ 2.000/mês          59      1
# 5     de R$ 2.001/mês a R$ 3.000/mês          75      2
# 8     de R$ 3.001/mês a R$ 4.000/mês          89      3
# 10    de R$ 4.001/mês a R$ 6.000/mês         244      4
# 11    de R$ 6.001/mês a R$ 8.000/mês         234      5
# 12   de R$ 8.001/mês a R$ 12.000/mês         320      6
# 3   de R$ 12.001/mês a R$ 16.000/mês         192      7
# 4   de R$ 16.001/mês a R$ 20.000/mês          49      8
# 6   de R$ 20.001/mês a R$ 25.000/mês          24      9
# 7   de R$ 25.001/mês a R$ 30.000/mês          13     10
# 9   de R$ 30.001/mês a R$ 40.000/mês          17     11
# 0             Acima de R$ 40.001/mês          12     12

# %%
with sns.axes_style('whitegrid'):
  plot = sns.barplot(data=salario_agg, x='Ordem', y='Quantidade', hue='Salário', palette='pastel')
  plot.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# **5.3. Por salário e cargo**

# %% [markdown]
# No segundo nível de agregação, incrementa-se o gráfico anterior com a informação do **cargo**

# %%
salario_cargo_agg.head(15)
# Out:
#          Cargo                         Salário  Quantidade  Ordem
# 1     Analista           Menos de R$ 1.000/mês           4      0
# 14   Cientista           Menos de R$ 1.000/mês           4      0
# 2     Analista  de R$ 1.001/mês a R$ 2.000/mês          28      1
# 15   Cientista  de R$ 1.001/mês a R$ 2.000/mês          16      1
# 27  Engenharia  de R$ 1.001/mês a R$ 2.000/mês          15      1
# 5     Analista  de R$ 2.001/mês a R$ 3.000/mês          36      2
# 18   Cientista  de R$ 2.001/mês a R$ 3.000/mês          24      2
# 30  Engenharia  de R$ 2.001/mês a R$ 3.000/mês          15      2
# 8     Analista  de R$ 3.001/mês a R$ 4.000/mês          59      3
# 21   Cientista  de R$ 3.001/mês a R$ 4.000/mês          18      3
# 33  Engenharia  de R$ 3.001/mês a R$ 4.000/mês          12      3
# 10    Analista  de R$ 4.001/mês a R$ 6.000/mês         122      4
# 23   Cientista  de R$ 4.001/mês a R$ 6.000/mês          59      4
# ...

# %%
with sns.axes_style('whitegrid'):
  plot = sns.barplot(data=salario_cargo_agg, x='Cargo', y='Quantidade', hue='Salário', palette='pastel')
  plot.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# **5.3. Por salário, cargo e experiência**

# %% [markdown]
# Por fim, no terceiro nível, aplicando a mesma técnica do gráfico anterior, mas agora
# distribuídos por **experiência** (eixo **x**) e **cargo** ( DataFrame dedicado).

# %% [markdown]
# * Analista

# %%
data = salario_cargo_experiencia_agg[salario_cargo_experiencia_agg['Cargo'] == 'Analista']

data
# Out:
#        Cargo Experiência                           Salário  Quantidade  Ordem
# 0   Analista      Júnior             Menos de R$ 1.000/mês           4      0
# 1   Analista      Júnior    de R$ 1.001/mês a R$ 2.000/mês          26      1
# 2   Analista      Júnior    de R$ 2.001/mês a R$ 3.000/mês          34      2
# 3   Analista      Júnior    de R$ 3.001/mês a R$ 4.000/mês          46      3
# 4   Analista      Júnior    de R$ 4.001/mês a R$ 6.000/mês          54      4
# 5   Analista      Júnior    de R$ 6.001/mês a R$ 8.000/mês          12      5
# 6   Analista      Júnior   de R$ 8.001/mês a R$ 12.000/mês           1      6
# 7   Analista       Pleno    de R$ 1.001/mês a R$ 2.000/mês           1      1
# 10  Analista       Pleno    de R$ 2.001/mês a R$ 3.000/mês           2      2
# 13  Analista       Pleno    de R$ 3.001/mês a R$ 4.000/mês          12      3
# 14  Analista       Pleno    de R$ 4.001/mês a R$ 6.000/mês          60      4
# ...

# %%
data = salario_cargo_experiencia_agg[salario_cargo_experiencia_agg['Cargo'] == 'Analista']

with sns.axes_style('whitegrid'):
  plot = sns.barplot(data=data, x='Experiência', y='Quantidade', hue='Salário', palette='pastel')
  plot.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# * Cientista

# %%
data = salario_cargo_experiencia_agg[salario_cargo_experiencia_agg['Cargo'] == 'Cientista']

with sns.axes_style('whitegrid'):
  plot = sns.barplot(data=data, x='Experiência', y='Quantidade', hue='Salário', palette='pastel')
  plot.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# * Engenheira

# %%
data = salario_cargo_experiencia_agg[salario_cargo_experiencia_agg['Cargo'] == 'Engenharia']

with sns.axes_style('whitegrid'):
  plot = sns.barplot(data=data, x='Experiência', y='Quantidade', hue='Salário', palette='pastel')
  plot.legend(loc='center left', bbox_to_anchor=(1, 0.5))
